# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv # to get API keys from .env file

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="groq:openai/gpt-oss-20b")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The Moon doesn’t have a capital city—it's not a country or a political entity with a government. It’s a celestial body, so there’s no capital to name!

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="groq:openai/gpt-oss-20b",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# **Capital of the Moon: Luna Nova**
#
# In the years after the First Lunar Settlement Act, the United Earth Lunar Authority (UELA) commissioned a single city to serve as the political, scientific, and cultural heart of humanity’s lunar presence. They called it **Luna Nova**—“New Moon” in Latin, a nod to both the celestial body and the rebirth of human civilization beyond Earth.
#
# ---
#
# ### 1. Location
# Luna Nova sits in the vast, basalt‑rich plain of **Mare Tranquillitatis** (Sea of Tranquility). The site was chosen for its relative stability, abundant regolith, and proximity to the ancient Apollo 11 landing site, giving the city a symbolic link to the first human steps on the Moon.
#
# ### 2. Architecture & Layout
# * **Modular Ring‑Habitat** – The city’s core is a series of concentric rings, each a self‑contained habitat module that can be reconfigured as the colony expands. The rings are connected by transparent, pressurised tunnels that double as light shafts, allowing natural lunar light to filter through during the long lunar nights.
# * **The “Helios Dome”** – A massive, geodesic glass dome covers the central plaza, housing the Lunar Parliament and the “Helios Library,” a repository of Earth’s knowledge and a growing archive of lunar research.
# * **Vertical Farms & Hydroponics** – The city’s vertical farms rise above the rings, producing fresh food and oxygen. They’re arranged in spirals that mimic the Moon’s slow rotation, giving the inhabitants a sense of rhythm and continuity.
# * **Surface Outposts** – Satellite research stations and mining hubs radiate outward from Luna Nova, connected by a network of high‑speed mag‑lev corridors that glide over the regolith.
#
# ### 3. Governance
# Luna Nova is governed by the **Lunar Council**, a body elected by all permanent residents. The council convenes in the Helios Dome and is responsible for legislation, resource allocation, and inter‑colony diplomacy. The Council’s charter emphasizes sustainability, scientific progress, and the preservation of the Moon’s pristine environment.
#
# ### 4. Culture & Society
# * **Lunar Arts Festival** – Every 27.3 Earth days (one lunar cycle), the city celebrates the “Lunar Arts Festival,” a week of music, dance, and visual art that reflects the slow, graceful motion of the Moon.
# * **Zero‑Gravity Sports** – The city’s sports complex features a zero‑gravity arena where athletes compete in games that would be impossible on Earth, such as “Lunar Sumo” and “Orbitball.”
# * **Educational Hubs** – Luna Nova hosts the **Lunar Institute of Advanced Studies**, where scholars from Earth and other colonies study lunar geology, astrobiology, and space engineering.
#
# ### 5. Daily Life
# * **Light & Sound** – With only two “days” a month, residents adapt to a rhythm of extended darkness and intense daylight. The city’s lighting system uses adaptive LED arrays that mimic sunrise and sunset, easing the psychological transition.
# * **Transportation** – Personal pods glide on magnetic rails, and the city’s “Lunar Bus” circulates on a loop that takes about 30 minutes to complete a circuit, allowing citizens to travel between the rings and the Helios Dome in a single hop.
# * **Civic Pride** – Every resident wears a small, iridescent patch on their clothing—an emblem of Luna Nova—signifying their membership in this unique lunar community.
#
# ---
#
# So, while there’s no official “capital” on the Moon in any earthly sense, **Luna Nova** stands as humanity’s first true lunar metropolis—a shining beacon of exploration, cooperation, and hope on the silent, silver face of our nearest celestial neighbor.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="groq:openai/gpt-oss-20b",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Scifi Writer: The Moon’s capital is **Lunaris**—a sprawling orbital metropolis that hovers just above the regolith, its gleaming spires reflecting the Earth‑bound glow. The city’s core is a network of transparent domes that house the Lunar Assembly, a council of planetary governors who chart the Moon’s destiny. Beneath the glass, gardens of hydroponic vines and crystal aquifers sustain the citizens, while the outer rings of the city anchor massive habitats that spin slowly, creating a subtle artificial gravity. Lunaris isn’t just a seat of power; it’s a beacon of human ingenuity, a shining testament to what can be built when the sky is no longer the limit.

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=("groq:openai/gpt-oss-20b"),
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Lunaris Prime
# Location: Mare Tranquillitatis, near the lunar equator, constructed within a vast basaltic plain and anchored to the regolith by a network of tethered habitats.
# Vibe: Quiet, resilient, luminous
# Economy: Regolith mining, orbital research laboratories, lunar tourism, and solar‑energy export to the inner Solar System.

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=('groq:openai/gpt-oss-20b'),
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Selene Prime', location='North polar region, near Shackleton Crater', vibe='Ethereal, serene, with bioluminescent algae farms', economy='Resource extraction and scientific research, trade in helium‑3 and lunar regolith')

# %%
response["structured_response"].name
# Out:
# 'Selene Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Selene Prime is a city located at North polar region, near Shackleton Crater
